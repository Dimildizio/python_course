# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimildizio/python_course/blob/main/basics/Functions_HW_gamification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple game
#
# В данном задании необходимо написать ряд функций для использования в качестве игры

# %% [markdown]
# ## Step 1: imports
#
# Импортируем модули, которые пригодятся:
#
# random - для случайных значений урона и врагов
# time - для создания пауз, чтобы бой выглядел живее

# %% [markdown]
# ## Step 2: Time

# %% [markdown]
# * Изучи и нагугли как взять текущее время. В каком формате оно выдается?
# * Добавь к нему 40 000 лет

# %% [markdown]
# ### Напиши приветствие которое гласит где игрок, используя f-strings сообщи какой сейчас год (в читаемом формате)

# %% [markdown]
# ## Step 3: constants
#
# Создай глобальные константы для (словарей) персонажей и врагов, ктороые будут иметь параметры `name`, `hp`, `attack`.
#
# ### Характеристики:
# Персонажи:
#  - Space Marine хп 100, атака 20
#  - Sister Of Battle хп 90, атака 18
#  - Ork хп 120, атака 15
#  - Guardsman хп 80 атака 12
#
#  Враги:
# - Cultist хп 70, атака 12
# - Tyranid хп 100, атака 18
# - Necron хп 110, "атака 16

# %%
SPACE_MARINE =
SISTER =
...

# %% [markdown]
# #### Создай списки содержащие всех персонажей и всех врагов

# %%
CHARACTERS =
ENEMIES =

# %% [markdown]
# ### Другие константы
#
# - Создай переменную `OFFSET` созначение `5`, которую потом будешь прибавлять и отнимать для рандома

# %% [markdown]
# ## Step 4: basic funcs
#
# Определи функцию `show_names` которая бы в цикле выводила только имена из заданного списка
# - Функция принимает на вход один аргумент - список со словарями внутри
# - для каждого элемента (словарь) в списке необходимо вывести порядковый номер и значение с именем по ключу `name`
# - функция ничего не возвращает
#
# Ожидаемый результат если передать ENEMIES на вход:
#
# `1 Cultist`
#
# `2 Tyranid`
#
# `3 Necron`

# %%
show_names(ENEMIES)  # тестируем

# %% [markdown]
# Определи функцию `map_characters` с одним аргументом num (*строку* с цифрой) она будет **возвращать** соотвествующий словарь в зависимости от ввода
# - Если у нас значение *строки* 1: вернуть словарь (у тебя уже есть глобальная переменная) со спейс марином
# - Если 2 - Сестру битвы
# - Если 3 - Орка
# - При любом другом результате - Гвардейца
#
# Ожидаемый результат при вводе строки 3 - словарь содержащий `name`, `hp`, `attack` орка
#
# Хинт:
# - Используй if/elif/else
# - Принт в данной функции не нужен

# %%
map_characters     # test it

# %% [markdown]
# ## Step 5: choose character
#
# Напиши функцию `choose_character` (без аргументов) которая бы повзолила с помощью `input` выбрать своего персонажа:
#
# 1. определи функцию
# 2. выведи текст с предложением выбрать персонажа
# 3. используя функцию show_names перечисли персонажей с их номерами
# 4. Используя `input` выведи текст "Select your number: " и ожидай ввода игрока
# 5. Используя результат что ввел игрок как аргумент внутри нашей функции сохрани результат функцию `map_character` в переменную `character`
# 6. Используя f-string выведи принтом текст с информацией о выборе персонажа и его характеристики. Ожидаемый результат в стиле "Your chosen character: Ork, attack is 15, hp is 120"
# 7. Функция должна вернуть переменную `character`
# 8. Результат работы функции сохрани в переменную`HERO`

# %%
def

# %%
HERO =

# %% [markdown]
# ## Step 6: create enemy
#
# Напиши функцию `generate_enemy` которая принииает на вход один аргумент - список и используя метод из встроенной библиотеки `random` выбирала бы случайным образом врага.
#
# 1. Определи функцию
# 2. Погугли какой метод из либы `random` выбирает случайный элемент из списка
# 3. Верни получившийся результат
# 4. Результат работы `generate_enemy` со списком врагов (константа определенная ранее) сохрани в переменную `FOE`
# 5. Выведи текст "Your opponent is: " с `FOE`

# %% [markdown]
# ## Step 7: attack
#
# Напиши функцию `attack` для одного удара. На вход принимает два аргумента - атакующий и защищающийся.
#
# - Определи функцию с аргументами
# - Погугли какая функция из `random` дает целочисленные значения (int) в заданном диапазоне и как этот диапазон задавать
# - Сгенерируй количество урона в диапазоне от `attack` атакующего минус `OFFSET` до `attack` атакующего плюс `OFFSET`
# - Отними этот урон от здоровья защищающегося
# - Используя f-string выведи фразу вроде *"Ork hits Tyranid for 18 dmg"* или *"Cultist hits Guardsman for 12 dmg"*
#
# hint:
# - При тестировании не забывай вернуть хп своему герою

# %%
  # test it

# %% [markdown]
# ## Step 8: death
#
# Напиши функцию `is_alive` проверяющую жив ли персонаж или враг. Функция принимает как аргумент словарь с врагом или героем и проверяет выше ли его хп чем 0 если да - возвращает `True` если нет - `False`

# %%
        # test it

# %% [markdown]
# ## Step 9: battle cycle
#
# Напиши функцию `battle` содержащую цикл битвы:
#
# 1. Определи функцию с двумя аргументами - игрок и враг
# 2. Используя цикл продолжаю выполнение до тех пор пока живы оба и враг и герой
# 3. В цикле сперва герой наносит урон используя функцию `attack`
# 4. затем проверяем жив ли враг
# 5. Если враг мертв - пишем об этом сообщение и обрываем цикл
# 6. Если враг - жив - он бьет героя
# 7. Проверяем жив ли герой
# 8. Если герой мертв - пишем об этом сообщение и обрываем цикл
# 9. Используя встроенную библиотеку time ждем 1 секунду (погугли какой метод из этой библиотеки позволяет это сделать)
#
# hints:
# - помни что цикл обязан когда нибудь завершиться (он выполняется пока соблюдены ОБА наших условия)
# - подумай как обраывать цикл
# - возможно ты захочешь увидеть сколько хп осталось у победителя

# %% [markdown]
# ## Step 10: mainloop
#
# Напиши функцию `mainloop` которая имеет цикл и ожидает в нем ввод `input` от игрока
#
# 1. Определи функцию
# 2. используй вечный цикл `while True:`
# 3. в цикле **ЗАНОВО** создай всех персонажей и врагов (SPACE_MARINE = ...) а также списки с ними
# 4. Используя свои функции **ЗАНОВО** определи `HERO`и `FOE`
# 5. Выведи "Battle begins"
# 6. Запусти `battle`
# 7. Выведи `Battle ends`
# 8. Ожидай `input` от игрока *"Play again? (y/n): "*
# 9. Если ответ не `y` - прерывай цикл
#
# hint:
# - подумай как еще кроме `break` можно прервать цикл (и завершить функцию)

# %%
mainloop()
